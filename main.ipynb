# %% [markdown]
# <a href="https://colab.research.google.com/github/Afag-Ramazanova/Cloud-Hosted-Notebook-Data-Manipulation/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the GitHub repository to access the mylib module
# !rm -rf Cloud-Hosted-Notebook-Data-Manipulation
# !git clone https://github.com/Afag-Ramazanova/Cloud-Hosted-Notebook-Data-Manipulation.git
# # Change the working directory to the cloned repository
# %cd Cloud-Hosted-Notebook-Data-Manipulation


# Now you can import your functions from mylib.lib
from my_lib.lib import (
    get_data,
    get_mean,
    get_median,
    summary,
    vizualisation,
    create_histogram,
    correlation_matrix,
)
import matplotlib.pyplot as plt
# Out:
# Cloning into 'Cloud-Hosted-Notebook-Data-Manipulation'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 55 (delta 19), reused 36 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 210.75 KiB | 2.45 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %% [markdown]
# ## Reading data

# %%
data = get_data(
    "https://raw.githubusercontent.com/Utshav-paudel/10-data-analysis-project/d7379235a8d48290c5333b83685d6fca76b5f2f9/dataset/2.%20Cars%20Data1.csv"
)

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## Plot distribution of numerical variables

# %%
data.hist(bins=20, figsize=(10, 8), color="blue")
plt.suptitle("Distribution of Numerical Variables", fontsize=16)
# plt.savefig("All_features_distribution.png")
plt.show()

# %% [markdown]
# ### One feature histogram

# %%
create_histogram(data)

# %% [markdown]
# ## Summary statistics

# %%
summary(data)
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %% [markdown]
# ## Correlation matrix

# %%
correlation_matrix(data)

# %% [markdown]
# ## Interaction of 2 features

# %%
vizualisation(data)
